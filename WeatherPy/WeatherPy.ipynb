# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Url and units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# List for holding reponse information
lat = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lon = []
date = []
country = []
cloudiness = []


# Loop through the list of cities and request for data on each
print("Beginning Data Retrieval")
print("--------------------------------------------")
count = 0
set = 1
for idx, city in enumerate(cities):
    count = count + 1
    # Avoid api call rate limits by getting city weather data for 50 cities,
    # then sleep for 5 seconds, and then call the next 50 cities, etc.
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
print("------------------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------------------")
# Out:
# entrance
# Processing Record 38 of Set 4 | bulungu
# Processing Record 39 of Set 4 | vilhena
# Processing Record 40 of Set 4 | selaphum
# Processing Record 41 of Set 4 | pospelikha
# Processing Record 42 of Set 4 | uva
# Processing Record 43 of Set 4 | oga
# Processing Record 44 of Set 4 | tarana
# Processing Record 45 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 4 | korla
# Processing Record 47 of Set 4 | burnie
# Processing Record 48 of Set 4 | acaponeta
# Processing Record 49 of Set 4 | viedma
# Processing Record 50 of Set 4 | portland
# Processing Record 1 of Set 5 | kavaratti
# Processing Record 2 of Set 5 | liepaja
# Processing Record 3 of Set 5 | acuna
# City not found. Skipping...
# Processing Record 4 of Set 5 | georgetown
# Processing Record 5 of Set 5 | pakxan
# Processing Record 6 of Set 5 | richmond
# Processing Record 7 of Set 5 | aleksandrovka
# Processing Record 8 of Set 5 | inhambane
# Processing Record 9 of Set 5 | macenta
# Processing Record 10 of Set 5 | mokhsogollokh
# Processing Record 11 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 5 | aksu
# Processing Record 13 of Set 5 | lavrentiya
# Processing Record 14 of Set 5 | carutapera
# Processing Record 15 of Set 5 | fukuma
# Processing Record 16 of Set 5 | sept-iles
# Processing Record 17 of Set 5 | katiola
# Processing Record 18 of Set 5 | roald
# Processing Record 19 of Set 5 | taitung
# Processing Record 20 of Set 5 | manokwari
# Processing Record 21 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 5 | noumea
# Processing Record 23 of Set 5 | paamiut
# Processing Record 24 of Set 5 | vestmannaeyjar
# Processing Record 25 of Set 5 | catabangan
# Processing Record 26 of Set 5 | woippy
# Processing Record 27 of Set 5 | kalianget
# Processing Record 28 of Set 5 | koumac
# Processing Record 29 of Set 5 | atuona
# Processing Record 30 of Set 5 | talaya
# Processing Record 31 of Set 5 | poum
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | puebloviejo
# Processing Record 34 of Set 5 | marsa matruh
# Processing Record 35 of Set 5 | namibe
# Processing Record 36 of Set 5 | walvis bay
# Processing Record 37 of Set 5 | esna
# Processing Record 38 of Set 5 | bairiki
# Processing Record 39 of Set 5 | datong
# Processing Record 40 of Set 5 | kirkkonummi
# Processing Record 41 of Set 5 | benalla
# Processing Record 42 of Set 5 | arosa
# Processing Record 43 of Set 5 | ribeira grande
# Processing Record 44 of Set 5 | lata
# Processing Record 45 of Set 5 | ca mau
# Processing Record 46 of Set 5 | newport
# Processing Record 47 of Set 5 | ndele
# Processing Record 48 of Set 5 | kahului
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 50 of Set 5 | tazmalt
# Processing Record 1 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 6 | karaton
# Processing Record 3 of Set 6 | nikolskoye
# Processing Record 4 of Set 6 | ponta do sol
# Processing Record 5 of Set 6 | novyy urgal
# Processing Record 6 of Set 6 | avarua
# Processing Record 7 of Set 6 | matara
# Processing Record 8 of Set 6 | kovdor
# Processing Record 9 of Set 6 | manakara
# Processing Record 10 of Set 6 | vardo
# Processing Record 11 of Set 6 | akyab
# Processing Record 12 of Set 6 | mayo
# Processing Record 13 of Set 6 | cascais
# Processing Record 14 of Set 6 | ugoofaaru
# Processing Record 15 of Set 6 | fatikchhari
# City not found. Skipping...
# Processing Record 16 of Set 6 | fare
# Processing Record 17 of Set 6 | bjornevatn
# Processing Record 18 of Set 6 | ostrovnoy
# Processing Record 19 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 6 | rusape
# Processing Record 22 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 6 | mahon
# Processing Record 24 of Set 6 | orchard homes
# Processing Record 25 of Set 6 | sasykoli
# Processing Record 26 of Set 6 | san quintin
# Processing Record 27 of Set 6 | ostersund
# Processing Record 28 of Set 6 | souillac
# Processing Record 29 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 6 | kamenka
# Processing Record 31 of Set 6 | kloulklubed
# Processing Record 32 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 6 | guadalupe victoria
# Processing Record 34 of Set 6 | tadine
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | bam
# Processing Record 37 of Set 6 | ewa beach
# Processing Record 38 of Set 6 | tongliao
# Processing Record 39 of Set 6 | shelburne
# Processing Record 40 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 6 | dhidhdhoo
# Processing Record 42 of Set 6 | sumbe
# Processing Record 43 of Set 6 | saskylakh
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | hasaki
# Processing Record 46 of Set 6 | sakakah
# Processing Record 47 of Set 6 | eha amufu
# Processing Record 48 of Set 6 | avera
# Processing Record 49 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 6 | luwuk
# Processing Record 1 of Set 7 | buin
# Processing Record 2 of Set 7 | severo-kurilsk
# Processing Record 3 of Set 7 | vila do maio
# Processing Record 4 of Set 7 | santa lucia
# Processing Record 5 of Set 7 | smithers
# Processing Record 6 of Set 7 | berlevag
# Processing Record 7 of Set 7 | itacare
# Processing Record 8 of Set 7 | powell river
# Processing Record 9 of Set 7 | chokurdakh
# Processing Record 10 of Set 7 | gorin
# Processing Record 11 of Set 7 | anadyr
# Processing Record 12 of Set 7 | port macquarie
# Processing Record 13 of Set 7 | nabire
# Processing Record 14 of Set 7 | concepcion del oro
# Processing Record 15 of Set 7 | tahoua
# Processing Record 16 of Set 7 | banda aceh
# Processing Record 17 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 7 | necochea
# Processing Record 19 of Set 7 | tabou
# Processing Record 20 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 7 | carroll
# Processing Record 22 of Set 7 | port-gentil
# Processing Record 23 of Set 7 | mahebourg
# Processing Record 24 of Set 7 | santiago del estero
# Processing Record 25 of Set 7 | dicabisagan
# Processing Record 26 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 27 of Set 7 | vila franca do campo
# Processing Record 28 of Set 7 | tazovskiy
# Processing Record 29 of Set 7 | tieli
# Processing Record 30 of Set 7 | bowen
# Processing Record 31 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 32 of Set 7 | lorengau
# Processing Record 33 of Set 7 | los llanos de aridane
# Processing Record 34 of Set 7 | praia da vitoria
# Processing Record 35 of Set 7 | beloha
# Processing Record 36 of Set 7 | hamilton
# Processing Record 37 of Set 7 | ibra
# Processing Record 38 of Set 7 | maputo
# Processing Record 39 of Set 7 | wilmington
# Processing Record 40 of Set 7 | topolovgrad
# Processing Record 41 of Set 7 | saint george
# Processing Record 42 of Set 7 | yermakovskoye
# Processing Record 43 of Set 7 | jaque
# Processing Record 44 of Set 7 | olafsvik
# Processing Record 45 of Set 7 | elko
# Processing Record 46 of Set 7 | marathon
# Processing Record 47 of Set 7 | kerema
# Processing Record 48 of Set 7 | bursa
# Processing Record 49 of Set 7 | tabuk
# Processing Record 50 of Set 7 | kresttsy
# Processing Record 1 of Set 8 | yulara
# Processing Record 2 of Set 8 | medina
# Processing Record 3 of Set 8 | saint-pacome
# City not found. Skipping...
# Processing Record 4 of Set 8 | wazzan
# City not found. Skipping...
# Processing Record 5 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 8 | kalcheva
# Processing Record 7 of Set 8 | talnakh
# Processing Record 8 of Set 8 | daltenganj
# Processing Record 9 of Set 8 | peleduy
# Processing Record 10 of Set 8 | dikson
# Processing Record 11 of Set 8 | palmer
# Processing Record 12 of Set 8 | vila velha
# Processing Record 13 of Set 8 | yeniseysk
# Processing Record 14 of Set 8 | leningradskiy
# Processing Record 15 of Set 8 | natal
# Processing Record 16 of Set 8 | baza
# Processing Record 17 of Set 8 | antigonish
# Processing Record 18 of Set 8 | madaoua
# Processing Record 19 of Set 8 | naze
# Processing Record 20 of Set 8 | tuy hoa
# Processing Record 21 of Set 8 | cam ranh
# Processing Record 22 of Set 8 | teguldet
# Processing Record 23 of Set 8 | zaysan
# Processing Record 24 of Set 8 | khandbari
# Processing Record 25 of Set 8 | butterworth
# Processing Record 26 of Set 8 | kilakarai
# Processing Record 27 of Set 8 | sabang
# Processing Record 28 of Set 8 | harper
# Processing Record 29 of Set 8 | kyzyl-suu
# Processing Record 30 of Set 8 | kieta
# Processing Record 31 of Set 8 | cabedelo
# Processing Record 32 of Set 8 | estevan
# Processing Record 33 of Set 8 | alcantara
# Processing Record 34 of Set 8 | kupino
# Processing Record 35 of Set 8 | twin falls
# Processing Record 36 of Set 8 | mecca
# Processing Record 37 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 8 | shimoda
# Processing Record 39 of Set 8 | kyren
# Processing Record 40 of Set 8 | tocopilla
# Processing Record 41 of Set 8 | olga
# Processing Record 42 of Set 8 | clyde river
# Processing Record 43 of Set 8 | manati
# Processing Record 44 of Set 8 | tungor
# Processing Record 45 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 8 | coos bay
# Processing Record 47 of Set 8 | laguna
# Processing Record 48 of Set 8 | ola
# Processing Record 49 of Set 8 | urumqi
# Processing Record 50 of Set 8 | alyangula
# Processing Record 1 of Set 9 | shorkot
# Processing Record 2 of Set 9 | jega
# Processing Record 3 of Set 9 | fortuna
# Processing Record 4 of Set 9 | krasnovishersk
# Processing Record 5 of Set 9 | miyang
# Processing Record 6 of Set 9 | high level
# Processing Record 7 of Set 9 | vila
# Processing Record 8 of Set 9 | beringovskiy
# Processing Record 9 of Set 9 | balgazyn
# Processing Record 10 of Set 9 | tukrah
# Processing Record 11 of Set 9 | muroto
# Processing Record 12 of Set 9 | adrar
# Processing Record 13 of Set 9 | keshod
# Processing Record 14 of Set 9 | le port
# Processing Record 15 of Set 9 | biak
# Processing Record 16 of Set 9 | paraiso
# Processing Record 17 of Set 9 | quatre cocos
# Processing Record 18 of Set 9 | camopi
# Processing Record 19 of Set 9 | dingle
# Processing Record 20 of Set 9 | hami
# Processing Record 21 of Set 9 | borovoy
# Processing Record 22 of Set 9 | bestobe
# Processing Record 23 of Set 9 | yongchang
# Processing Record 24 of Set 9 | conneaut
# Processing Record 25 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 9 | kunya
# Processing Record 27 of Set 9 | ulladulla
# Processing Record 28 of Set 9 | altamira
# Processing Record 29 of Set 9 | hare bay
# Processing Record 30 of Set 9 | leeton
# Processing Record 31 of Set 9 | nanakuli
# Processing Record 32 of Set 9 | bushenyi
# Processing Record 33 of Set 9 | amarpatan
# Processing Record 34 of Set 9 | sandila
# Processing Record 35 of Set 9 | sioux lookout
# Processing Record 36 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 9 | xichang
# Processing Record 38 of Set 9 | takoradi
# Processing Record 39 of Set 9 | pleasanton
# Processing Record 40 of Set 9 | buala
# Processing Record 41 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 42 of Set 9 | kedrovyy
# Processing Record 43 of Set 9 | alta gracia
# Processing Record 44 of Set 9 | pacific grove
# Processing Record 45 of Set 9 | bako
# Processing Record 46 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 9 | benghazi
# Processing Record 48 of Set 9 | virginia beach
# Processing Record 49 of Set 9 | cananeia
# Processing Record 50 of Set 9 | rincon de la victoria
# Processing Record 1 of Set 10 | san patricio
# Processing Record 2 of Set 10 | mahajanga
# Processing Record 3 of Set 10 | clacton-on-sea
# Processing Record 4 of Set 10 | yangjiang
# Processing Record 5 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 10 | tilichiki
# Processing Record 7 of Set 10 | valparaiso
# Processing Record 8 of Set 10 | manaure
# Processing Record 9 of Set 10 | bonavista
# Processing Record 10 of Set 10 | kiruna
# Processing Record 11 of Set 10 | gijon
# Processing Record 12 of Set 10 | libreville
# Processing Record 13 of Set 10 | kathmandu
# Processing Record 14 of Set 10 | baytown
# Processing Record 15 of Set 10 | guanica
# Processing Record 16 of Set 10 | kilindoni
# Processing Record 17 of Set 10 | panjab
# Processing Record 18 of Set 10 | polovinnoye
# Processing Record 19 of Set 10 | altus
# Processing Record 20 of Set 10 | lima
# Processing Record 21 of Set 10 | nikolayevka
# Processing Record 22 of Set 10 | jiangkou
# Processing Record 23 of Set 10 | kiunga
# Processing Record 24 of Set 10 | qui nhon
# Processing Record 25 of Set 10 | mezen
# Processing Record 26 of Set 10 | deputatskiy
# Processing Record 27 of Set 10 | norrtalje
# Processing Record 28 of Set 10 | warwick
# Processing Record 29 of Set 10 | nhulunbuy
# Processing Record 30 of Set 10 | tiksi
# Processing Record 31 of Set 10 | sorland
# Processing Record 32 of Set 10 | biga
# Processing Record 33 of Set 10 | vostok
# Processing Record 34 of Set 10 | enshi
# Processing Record 35 of Set 10 | kuvandyk
# Processing Record 36 of Set 10 | guangyuan
# Processing Record 37 of Set 10 | asyut
# Processing Record 38 of Set 10 | ilo
# Processing Record 39 of Set 10 | along
# Processing Record 40 of Set 10 | ancud
# Processing Record 41 of Set 10 | miyako
# Processing Record 42 of Set 10 | nome
# Processing Record 43 of Set 10 | dudinka
# Processing Record 44 of Set 10 | tokur
# Processing Record 45 of Set 10 | sisimiut
# Processing Record 46 of Set 10 | mount gambier
# Processing Record 47 of Set 10 | teahupoo
# Processing Record 48 of Set 10 | las choapas
# Processing Record 49 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 50 of Set 10 | erenhot
# Processing Record 1 of Set 11 | gilbues
# Processing Record 2 of Set 11 | san jeronimo
# Processing Record 3 of Set 11 | vanimo
# Processing Record 4 of Set 11 | ayan
# Processing Record 5 of Set 11 | buncrana
# Processing Record 6 of Set 11 | flinders
# Processing Record 7 of Set 11 | malakal
# Processing Record 8 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 9 of Set 11 | sussex
# Processing Record 10 of Set 11 | sindand
# City not found. Skipping...
# Processing Record 11 of Set 11 | mahibadhoo
# Processing Record 12 of Set 11 | payson
# Processing Record 13 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 14 of Set 11 | rudbar
# Processing Record 15 of Set 11 | warri
# Processing Record 16 of Set 11 | ngunguru
# Processing Record 17 of Set 11 | beyneu
# Processing Record 18 of Set 11 | ippy
# Processing Record 19 of Set 11 | stony plain
# Processing Record 20 of Set 11 | caravelas
# Processing Record 21 of Set 11 | itarema
# Processing Record 22 of Set 11 | dunedin
# Processing Record 23 of Set 11 | moree
# Processing Record 24 of Set 11 | bilma
# Processing Record 25 of Set 11 | tiznit
# Processing Record 26 of Set 11 | isangel
# Processing Record 27 of Set 11 | darnah
# Processing Record 28 of Set 11 | richards bay
# Processing Record 29 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 11 | callaway
# Processing Record 31 of Set 11 | kutum
# Processing Record 32 of Set 11 | kozhva
# Processing Record 33 of Set 11 | santiago de cao
# Processing Record 34 of Set 11 | bajil
# Processing Record 35 of Set 11 | claveria
# Processing Record 36 of Set 11 | minab
# Processing Record 37 of Set 11 | ayorou
# Processing Record 38 of Set 11 | betioky
# Processing Record 39 of Set 11 | sao joao da barra
# Processing Record 40 of Set 11 | pedasi
# Processing Record 41 of Set 11 | skegness
# Processing Record 42 of Set 11 | kallithea
# Processing Record 43 of Set 11 | yelatma
# Processing Record 44 of Set 11 | muisne
# Processing Record 45 of Set 11 | ust-tsilma
# Processing Record 46 of Set 11 | beeville
# Processing Record 47 of Set 11 | auki
# Processing Record 48 of Set 11 | kaeo
# Processing Record 49 of Set 11 | katangli
# Processing Record 50 of Set 11 | manyana
# Processing Record 1 of Set 12 | kiboga
# Processing Record 2 of Set 12 | eidfjord
# Processing Record 3 of Set 12 | torbay
# Processing Record 4 of Set 12 | birao
# Processing Record 5 of Set 12 | praya
# Processing Record 6 of Set 12 | bossangoa
# Processing Record 7 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 12 | san lorenzo
# Processing Record 9 of Set 12 | ayagoz
# Processing Record 10 of Set 12 | gat
# Processing Record 11 of Set 12 | port lincoln
# Processing Record 12 of Set 12 | samarai
# Processing Record 13 of Set 12 | joao pinheiro
# Processing Record 14 of Set 12 | revelstoke
# Processing Record 15 of Set 12 | canora
# Processing Record 16 of Set 12 | mendeleyevsk
# Processing Record 17 of Set 12 | adelaide
# Processing Record 18 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 19 of Set 12 | zlynka
# Processing Record 20 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 21 of Set 12 | cabangahan
# Processing Record 22 of Set 12 | king city
# Processing Record 23 of Set 12 | jiayuguan
# Processing Record 24 of Set 12 | hay river
# Processing Record 25 of Set 12 | merauke
# Processing Record 26 of Set 12 | mao
# Processing Record 27 of Set 12 | gazanjyk
# Processing Record 28 of Set 12 | hobyo
# Processing Record 29 of Set 12 | siutu
# City not found. Skipping...
# Processing Record 30 of Set 12 | mbaiki
# Processing Record 31 of Set 12 | ahipara
# Processing Record 32 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 33 of Set 12 | kristiinankaupunki
# Processing Record 34 of Set 12 | nelson bay
# Processing Record 35 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 12 | fort wellington
# Processing Record 37 of Set 12 | atambua
# Processing Record 38 of Set 12 | saint-pierre
# Processing Record 39 of Set 12 | port-cartier
# Processing Record 40 of Set 12 | george
# Processing Record 41 of Set 12 | tir pol
# City not found. Skipping...
# Processing Record 42 of Set 12 | srednekolymsk
# Processing Record 43 of Set 12 | coahuayana
# Processing Record 44 of Set 12 | zhezkazgan
# Processing Record 45 of Set 12 | paso de carrasco
# Processing Record 46 of Set 12 | lagunas
# Processing Record 47 of Set 12 | bontang
# Processing Record 48 of Set 12 | uruguaiana
# Processing Record 49 of Set 12 | qom
# Processing Record 50 of Set 12 | gushikawa
# Processing Record 1 of Set 13 | weiser
# Processing Record 2 of Set 13 | alihe
# Processing Record 3 of Set 13 | karratha
# Processing Record 4 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 13 | blind river
# Processing Record 6 of Set 13 | kirkwall
# Processing Record 7 of Set 13 | manggar
# Processing Record 8 of Set 13 | sibolga
# Processing Record 9 of Set 13 | elbrus
# Processing Record 10 of Set 13 | koslan
# Processing Record 11 of Set 13 | iqaluit
# Processing Record 12 of Set 13 | husavik
# Processing Record 13 of Set 13 | terrace bay
# Processing Record 14 of Set 13 | agara
# Processing Record 15 of Set 13 | san vicente
# Processing Record 16 of Set 13 | kuching
# Processing Record 17 of Set 13 | port augusta
# Processing Record 18 of Set 13 | marabba
# Processing Record 19 of Set 13 | san joaquin
# Processing Record 20 of Set 13 | raudeberg
# Processing Record 21 of Set 13 | emba
# Processing Record 22 of Set 13 | road town
# Processing Record 23 of Set 13 | naduvattam
# Processing Record 24 of Set 13 | jacareacanga
# Processing Record 25 of Set 13 | kurud
# Processing Record 26 of Set 13 | geraldton
# Processing Record 27 of Set 13 | sulphur
# Processing Record 28 of Set 13 | vreed en hoop
# City not found. Skipping...
# Processing Record 29 of Set 13 | puerto penasco
# Processing Record 30 of Set 13 | mount isa
# Processing Record 31 of Set 13 | mali
# Processing Record 32 of Set 13 | yelan-koleno
# Processing Record 33 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 34 of Set 13 | griffith
# Processing Record 35 of Set 13 | sobolevo
# Processing Record 36 of Set 13 | san jose
# Processing Record 37 of Set 13 | matamoros
# Processing Record 38 of Set 13 | pervomayskiy
# Processing Record 39 of Set 13 | pascagoula
# Processing Record 40 of Set 13 | oktyabrskiy
# ------------------------------------------------
# Data Retrieval Complete
# ------------------------------------------------

# %%
# Length of Latitude
len(lat)
# Out:
# 640

# %%
# Compare to Cities
len(cities)
# Out:
# 640

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert raw data to dataframe.
city_weather_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "lng": lon,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
})

# Drop any cities that were skipped because they could not be found using the OpenWeatherMap API.
city_weather_df = city_weather_df.dropna(how="any")
city_weather_df.to_csv("../output_data/city_weather_data.csv", index=False)
print(city_weather_df.count())
# Out:
# City          584
# Lat           584
# lng           584
# Max Temp      584
# Humidity      584
# Cloudiness    584
# Wind Speed    584
# Country       584
# Date          584
# dtype: int64

# %%
# Export the city data into a .csv file.


# Display the DataFrame
weather_df = pd.read_csv("../output_data/city_weather_data.csv")

weather_df.head()
# Out:
#           City      Lat       lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      rikitea -23.1203 -134.9692     79.11      68.0       100.0       17.56
# 1     tessalit  20.1986    1.0114     88.03       7.0         0.0        6.64
# 2  bandarbeyla   9.4942   50.8122     82.92      73.0       100.0        7.38
# 3       barrow  71.2906 -156.7887     19.40      79.0         1.0        3.44
# 4      salalah  17.0151   54.0924     82.40      74.0        40.0        5.75
#
#   Country          Date
# 0      PF  1.619215e+09
# 1      ML  1.619215e+09
# 2      SO  1.619215e+09
# 3      US  1.619215e+09
# 4      OM  1.619215e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Section Skipped

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
date_time = datetime.now

# Create a scatter plot for latitude vs max temperature.
x_values = weather_df['Lat']
y_values = weather_df['Max Temp']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"City Latitude vs Max Temperature {date_time}")
plt.grid()
plt.savefig("../output_data/latitude_vs_temperature.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a scatter plot for latitude vs humidity.
x_values = weather_df['Lat']
y_values = weather_df['Humidity']
fig1, ax1 = plt.subplots(figsize=(10, 8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity {date_time}')
plt.grid()
plt.savefig("../output_data/latitude_vs_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot for latitude vs cloudiness.
x_values = weather_df['Lat']
y_values = weather_df['Cloudiness']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness {date_time}')
plt.grid()
plt.savefig("../output_data/latitude_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot for latitude vs wind speed.
x_values = weather_df['Lat']
y_values = weather_df['Wind Speed']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed {date_time}')
plt.grid()
plt.savefig("../output_data/latitude_vs_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def createLinearRegressionPlot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    fig1, ax1 = plt.subplots(figsize=(10,8))
    plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
    plt.xlabel(x_label,fontsize = 14)
    plt.ylabel(y_label,fontsize = 14)
    if ylim is not None:
        plt.ylim(0, ylim)
    today = datetime.now()
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} {today}",fontsize = 15)
    plt.annotate(line_eq,xy=(10, 50),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(-50, 40),fontsize=22,xycoords='data',xytext=(0.4, 0.3), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(10, 25),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    # Print r square value
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    return plt.plot(x_values,regress_values,"r-")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_hemisphere_weather_df = weather_df.loc[weather_df["Lat"] >= 0]
southern_hemisphere_weather_df = weather_df.loc[weather_df["Lat"] < 0]

# %%
# Create a scatter plot for latitude vs max temp (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Max Temp']
createLinearRegressionPlot(x_values, y_values, "Lat", "Max Temp (F)", "Northern",(0, 0))
plt.savefig("../output_data/Northern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.7815587700489157
# The correlation between both factors is -0.88

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))

plt.savefig("../output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.0010507560893977305
# The correlation between both factors is 0.03

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humditiy (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(40, 20))
plt.savefig("../output_data/Northern_Hemisphere_Humidity_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.011440975443147096
# The correlation between both factors is 0.11

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humditiy (southern hemisphere)
x_values1 = southern_hemisphere_weather_df['Lat']
y_values1 = southern_hemisphere_weather_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(40, 20), 150)
plt.savefig("../output_data/southern_humudity_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.011440975443147096
# The correlation between both factors is 0.11

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Northern",(30, 50))

plt.savefig("../output_data/Northern Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.00921880745015694
# The correlation between both factors is 0.1

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
plt.savefig("../output_data/Southern_Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.0010507560893977305
# The correlation between both factors is 0.03

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed(northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))
plt.savefig("../output_data/Northern_Hemisphere_Wind_Speed_Latitude_Lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.0052331060649520224
# The correlation between both factors is 0.07

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25), ylim=40)
plt.savefig("../output_data/Southern_Hemisphere_Wind_Speed_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.01419522561983359
# The correlation between both factors is -0.12
